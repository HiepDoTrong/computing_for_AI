# %% [markdown]
# # Adult dataset
#
# Thông tin giá trị dưới đây là duy nhất cho từng features:
# - `age`: continuous.
# - `workclass`: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - `fnlwgt`: continuous.
# - `education`: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - `education-num`: continuous.
# - `marital-status`: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - `occupation`: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - `relationship`: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - `race`: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - `sex`: Female, Male.
# - `capital-gain`: continuous.
# - `capital-loss`: continuous.
# - `hours-per-week`: continuous.
# - `native-country`: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# - `salary`: >50K,<=50K

# %% [markdown]
# ### 1. (2đ) Import các thư viện cần thiết

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 2. (2đ) Đọc dữ liệu từ file này  [address](https://github.com/thieu1995/csv-files/blob/main/data/pandas/adult.data) và gán tên biến là df. Đồng thời thiết lập tên các features dựa trên thông tin đã cho ở đầu bài.

# %%
url = 'https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/adult.data'
df = pd.read_csv(url, header=None)
df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'salary']
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  salary
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %% [markdown]
# ### 3. (2đ) In ra giá trị 15 hàng dữ liệu đầu tiên của bảng

# %%
df.head(15)
# Out:
#     age          workclass  fnlwgt      education  education_num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# 5    37            Private  284582        Masters             14
# 6    49            Private  160187            9th              5
# 7    52   Self-emp-not-inc  209642        HS-grad              9
# 8    31            Private   45781        Masters             14
# 9    42            Private  159449      Bachelors             13
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# 12   23            Private  122272      Bachelors             13
# 13   32            Private  205019     Assoc-acdm             12
# 14   40            Private  121772      Assoc-voc             11
#
#             marital_status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# 1       Married-civ-spouse     Exec-managerial         Husband
# 2                 Divorced   Handlers-cleaners   Not-in-family
# 3       Married-civ-spouse   Handlers-cleaners         Husband
# 4       Married-civ-spouse      Prof-specialty            Wife
# 5       Married-civ-spouse     Exec-managerial            Wife
# 6    Married-spouse-absent       Other-service   Not-in-family
# 7       Married-civ-spouse     Exec-managerial         Husband
# 8            Never-married      Prof-specialty   Not-in-family
# 9       Married-civ-spouse     Exec-managerial         Husband
# 10      Married-civ-spouse     Exec-managerial         Husband
# 11      Married-civ-spouse      Prof-specialty         Husband
# 12           Never-married        Adm-clerical       Own-child
# 13           Never-married               Sales   Not-in-family
# 14      Married-civ-spouse        Craft-repair         Husband
#
#                    race      sex  capital_gain  capital_loss  hours_per_week  \
# 0                 White     Male          2174             0              40
# 1                 White     Male             0             0              13
# 2                 White     Male             0             0              40
# 3                 Black     Male             0             0              40
# 4                 Black   Female             0             0              40
# 5                 White   Female             0             0              40
# 6                 Black   Female             0             0              16
# 7                 White     Male             0             0              45
# 8                 White   Female         14084             0              50
# 9                 White     Male          5178             0              40
# 10                Black     Male             0             0              80
# 11   Asian-Pac-Islander     Male             0             0              40
# 12                White   Female             0             0              30
# 13                Black     Male             0             0              50
# 14   Asian-Pac-Islander     Male             0             0              40
#
#     native_country  salary
# 0    United-States   <=50K
# 1    United-States   <=50K
# 2    United-States   <=50K
# 3    United-States   <=50K
# 4             Cuba   <=50K
# 5    United-States   <=50K
# 6          Jamaica   <=50K
# 7    United-States    >50K
# 8    United-States    >50K
# 9    United-States    >50K
# 10   United-States    >50K
# 11           India    >50K
# 12   United-States   <=50K
# 13   United-States   <=50K
# 14               ?    >50K

# %% [markdown]
# ### 4. (2đ) In ra tất cả các giá trị unique của tất cả các cột trong bảng

# %%
for col in df.columns:
    print(f'{col}: {df[col].unique()}')
# Out:
# age: [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
# workclass: [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
# fnlwgt: [ 77516  83311 215646 ...  34066  84661 257302]
# education: [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# education_num: [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
# marital_status: [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
# occupation: [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Craft-repair' ' Transport-moving'
#  ' Farming-fishing' ' Machine-op-inspct' ' Tech-support' ' ?'
#  ' Protective-serv' ' Armed-Forces' ' Priv-house-serv']
# relationship: [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
# race: [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
# sex: [' Male' ' Female']
# capital_gain: [ 2174     0 14084  5178  5013  2407 14344 15024  7688 34095  4064  4386
#   7298  1409  3674  1055  3464  2050  2176   594 20051  6849  4101  1111
#   8614  3411  2597 25236  4650  9386  2463  3103 10605  2964  3325  2580
#   3471  4865 99999  6514  1471  2329  2105  2885 25124 10520  2202  2961
#  27828  6767  2228  1506 13550  2635  5556  4787  3781  3137  3818  3942
#    914   401  2829  2977  4934  2062  2354  5455 15020  1424  3273 22040
#   4416  3908 10566   991  4931  1086  7430  6497   114  7896  2346  3418
#   3432  2907  1151  2414  2290 15831 41310  4508  2538  3456  6418  1848
#   3887  5721  9562  1455  2036  1831 11678  2936  2993  7443  6360  1797
#   1173  4687  6723  2009  6097  2653  1639 18481  7978  2387  5060]
# capital_loss: [   0 2042 1408 1902 1573 1887 1719 1762 1564 2179 1816 1980 1977 1876
#  1340 2206 1741 1485 2339 2415 1380 1721 2051 2377 1669 2352 1672  653
#  2392 1504 2001 1590 1651 1628 1848 1740 2002 1579 2258 1602  419 2547
#  2174 2205 1726 2444 1138 2238  625  213 1539  880 1668 1092 1594 3004
#  2231 1844  810 2824 2559 2057 1974  974 2149 1825 1735 1258 2129 2603
#  2282  323 4356 2246 1617 1648 2489 3770 1755 3683 2267 2080 2457  155
#  3900 2201 1944 2467 2163 2754 2472 1411]
# hours_per_week: [40 13 16 45 50 80 30 35 60 20 52 44 15 25 38 43 55 48 58 32 70  2 22 56
#  41 28 36 24 46 42 12 65  1 10 34 75 98 33 54  8  6 64 19 18 72  5  9 47
#  37 21 26 14  4 59  7 99 53 39 62 57 78 90 66 11 49 84  3 17 68 27 85 31
#  51 77 63 23 87 88 73 89 97 94 29 96 67 82 86 91 81 76 92 61 74 95]
# native_country: [' United-States' ' Cuba' ' Jamaica' ' India' ' ?' ' Mexico' ' South'
#  ' Puerto-Rico' ' Honduras' ' England' ' Canada' ' Germany' ' Iran'
#  ' Philippines' ' Italy' ' Poland' ' Columbia' ' Cambodia' ' Thailand'
#  ' Ecuador' ' Laos' ' Taiwan' ' Haiti' ' Portugal' ' Dominican-Republic'
#  ' El-Salvador' ' France' ' Guatemala' ' China' ' Japan' ' Yugoslavia'
#  ' Peru' ' Outlying-US(Guam-USVI-etc)' ' Scotland' ' Trinadad&Tobago'
#  ' Greece' ' Nicaragua' ' Vietnam' ' Hong' ' Ireland' ' Hungary'
#  ' Holand-Netherlands']
# salary: [' <=50K' ' >50K']

# %% [markdown]
# ### 5. (2đ) Tạo biểu đồ histogram của cột hours-per-week (số giờ làm trong 1 tuần)

# %%
len(df)
# Out:
# 32561

# %%
df['hours_per_week'].hist()
plt.xlabel('Hours per week')
plt.ylabel('Frequency')
plt.title('Hours per week distribution')
plt.show()

# %% [markdown]
# ### 6. (3đ) Tạo biểu đồ histogram của cột hours-per-week của những người cố số năm giáo dục (education-num) >= 9.

# %%
df[df['education_num']>=9]['hours_per_week'].hist()
plt.xlabel('Hours per week')
plt.ylabel('Frequency')
plt.title('Hours per week distribution')
plt.show()

# %% [markdown]
# ### 7. (3đ) Tạo pie chart thể hiện phần trăm của cột race và sex (sẽ có 5*2=10 categories tổng thể trong 1 hình vẽ). Nhận xét xem nhóm nào chiếm tỉ lệ nhiều nhất.

# %%
race_sex = df.groupby(['race', 'sex']).count()
# race_sex[['race', 'sex']]
race_sex.age
# Out:
# race                sex
# Amer-Indian-Eskimo  Female      119
#                     Male        192
# Asian-Pac-Islander  Female      346
#                     Male        693
# Black               Female     1555
#                     Male       1569
# Other               Female      109
#                     Male        162
# White               Female     8642
#                     Male      19174
# Name: age, dtype: int64

# %%
proportions = race_sex.age
plt.figure(figsize=(15,15))
plt.pie(
    proportions,
    labels = race_sex.index,
    shadow = False,
    autopct = '%1.1f%%'
    )
plt.axis('equal')
plt.legend(loc='upper right')
plt.title("Race Sex Proportion")
plt.tight_layout()
plt.show()

# %% [markdown]
# Nhóm chiếm tỉ lệ nhiều nhất là White Male với 58.9%

# %% [markdown]
# ### 8. (3đ) Tạo pie chart cho cột workclass và nhận xét xem nhóm nào chiếm nhiều nhất.

# %%
work_class = df.groupby('workclass').count()
work_class['age']
# Out:
# workclass
# ?                    1836
# Federal-gov           960
# Local-gov            2093
# Never-worked            7
# Private             22696
# Self-emp-inc         1116
# Self-emp-not-inc     2541
# State-gov            1298
# Without-pay            14
# Name: age, dtype: int64

# %%
proportions = work_class.age
plt.figure(figsize=(15,15))
plt.pie(
    proportions,
    labels = work_class.index,
    shadow = False,
    autopct = '%1.1f%%'
    )
plt.axis('equal')
plt.legend(loc='upper right')
plt.title("Race Sex Proportion")
plt.tight_layout()
plt.show()

# %% [markdown]
# Nhóm chiếm tỉ lệ nhiều nhất là Private chiếm 69.7%

# %% [markdown]
# ### 9. (3đ) Tạo scatter chart cho cột education-num và cột age.

# %%
plt.scatter(df['education_num'], df['age'])
plt.xlabel('Education Num')
plt.ylabel('Age')
plt.title('Education Num vs Age')
plt.show()

# %% [markdown]
# ### 10. (3đ) Tạo scatter chart cho cột age và cột hours-per-week.

# %%
plt.scatter(df['age'], df['hours_per_week'])
plt.xlabel('Age')
plt.ylabel('Hour per week')
plt.title('Age vs Hour per week')
plt.show()

# %% [markdown]
# ### 11. (5đ) Tạo box plot cho cột race và cột education-num (Trục x là các categories của cột race, trục y là giá trị education-num).

# %%
df.boxplot(column='education_num', by='race', figsize=(10, 5))
# Out:
# <Axes: title={'center': 'education_num'}, xlabel='race'>

# %% [markdown]
# ### 12. (5đ) Tạo box plot cho cột workclass và cột hours-per-week (Trực x là các categories của cột workclass, trục y là giá trị hours-per-week).

# %%
df.boxplot(column='hours_per_week', by='workclass', figsize=(15, 5))
# Out:
# <Axes: title={'center': 'hours_per_week'}, xlabel='workclass'>

# %% [markdown]
# ### 13. (2đ) In ra 5 hàng cuối cùng của bảng dữ liệu

# %%
df.tail(5)
# Out:
#        age      workclass  fnlwgt    education  education_num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital_gain  capital_loss  hours_per_week  native_country  salary
# 32556             0             0              38   United-States   <=50K
# 32557             0             0              40   United-States    >50K
# 32558             0             0              40   United-States   <=50K
# 32559             0             0              20   United-States   <=50K
# 32560         15024             0              40   United-States    >50K

# %% [markdown]
# ### 14. (3đ) Hiển thị các giá trị thống kê đối với các features dạng số và cho biết giá trị mean của capital-gain là bao nhiêu?

# %%
df[['age', 'education_num', 'capital_gain', 'capital_loss', 'hours_per_week']].describe()
# Out:
#                 age  education_num  capital_gain  capital_loss  hours_per_week
# count  32561.000000   32561.000000  32561.000000  32561.000000    32561.000000
# mean      38.581647      10.080679   1077.648844     87.303830       40.437456
# std       13.640433       2.572720   7385.292085    402.960219       12.347429
# min       17.000000       1.000000      0.000000      0.000000        1.000000
# 25%       28.000000       9.000000      0.000000      0.000000       40.000000
# 50%       37.000000      10.000000      0.000000      0.000000       40.000000
# 75%       48.000000      12.000000      0.000000      0.000000       45.000000
# max       90.000000      16.000000  99999.000000   4356.000000       99.000000

# %% [markdown]
# Mean của Capital Gain là 1077.648844

# %% [markdown]
# ### 15. (5đ) Độ tuổi trung bình của women là bao nhiêu?

# %%
df[df['sex'] == ' Female']['age'].mean()
# Out:
# 36.85823043357163

# %% [markdown]
# ### 16. (5đ) Phần trăm dân số người German là bao nhiêu (native-country feature)?

# %%
germany = df[df['native_country'] == ' Germany'].shape[0]
germany
# Out:
# 137

# %%
all = df.shape[0]
all
# Out:
# 32561

# %%
print(f'Proportion of German people: {germany/all}')
# Out:
# Proportion of German people: 0.004207487485028101

# %% [markdown]
# ### 17. (6đ) Độ lệch chuẩn và giá trị trung bình của độ tuổi đối với những người kiếm được hơn 50K mỗi năm (*native-country* feature) và những người kiếm được ít hơn 50K mỗi năm là bao nhiêu?

# %%
df[df['salary'] == ' >50K']['age'].describe()
# Out:
# count    7841.000000
# mean       44.249841
# std        10.519028
# min        19.000000
# 25%        36.000000
# 50%        44.000000
# 75%        51.000000
# max        90.000000
# Name: age, dtype: float64

# %% [markdown]
# Độ lệch chuẩn và giá trị trung bình của độ tuổi đối với những người kiếm được hơn 50K mỗi năm là 44.249841 và 10.519028

# %%
df[df['salary'] == ' <=50K']['age'].describe()
# Out:
# count    24720.000000
# mean        36.783738
# std         14.020088
# min         17.000000
# 25%         25.000000
# 50%         34.000000
# 75%         46.000000
# max         90.000000
# Name: age, dtype: float64

# %% [markdown]
# Độ lệch chuẩn và giá trị trung bình của độ tuổi đối với những người kiếm được hơn 50K mỗi năm là 36.783738 và 14.020088

# %% [markdown]
# ### 18. (6đ) Có đúng là những người kiếm được hơn 50K đều có trình độ học vấn ít nhất là  high school? (education feature – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters or Doctorate)

# %%
df[df['salary'] == ' >50K']['education'].unique()
# Out:
# array([' HS-grad', ' Masters', ' Bachelors', ' Some-college',
#        ' Assoc-voc', ' Doctorate', ' Prof-school', ' Assoc-acdm',
#        ' 7th-8th', ' 12th', ' 10th', ' 11th', ' 9th', ' 5th-6th',
#        ' 1st-4th'], dtype=object)

# %% [markdown]
# Không phải tất cả những người kiếm được hơn 50K đều có trình độ học vấn ít nhất là high school, có những người chỉ học phổ thông 1st - 12th

# %% [markdown]
# ### 19. (6đ) Hiển thị thống kê độ tuổi cho từng chủng tộc (race feature) và từng giới tính (sex feature). Sử dụng groupby() describe(). Tìm độ tuổi tối đa của nam giới thuộc chủng tộc Amer-Indian-Eskimo.

# %%
df.groupby(['race', 'sex'])['age'].describe()
# Out:
#                              count       mean        std   min   25%   50%  \
# race               sex
# Amer-Indian-Eskimo Female    119.0  37.117647  13.114991  17.0  27.0  36.0
#                    Male      192.0  37.208333  12.049563  17.0  28.0  35.0
# Asian-Pac-Islander Female    346.0  35.089595  12.300845  17.0  25.0  33.0
#                    Male      693.0  39.073593  12.883944  18.0  29.0  37.0
# Black              Female   1555.0  37.854019  12.637197  17.0  28.0  37.0
#                    Male     1569.0  37.682600  12.882612  17.0  27.0  36.0
# Other              Female    109.0  31.678899  11.631599  17.0  23.0  29.0
#                    Male      162.0  34.654321  11.355531  17.0  26.0  32.0
# White              Female   8642.0  36.811618  14.329093  17.0  25.0  35.0
#                    Male    19174.0  39.652498  13.436029  17.0  29.0  38.0
#
#                              75%   max
# race               sex
# Amer-Indian-Eskimo Female  46.00  80.0
#                    Male    45.00  82.0
# Asian-Pac-Islander Female  43.75  75.0
#                    Male    46.00  90.0
# Black              Female  46.00  90.0
#                    Male    46.00  90.0
# Other              Female  39.00  74.0
#                    Male    42.00  77.0
# White              Female  46.00  90.0
#                    Male    49.00  90.0

# %% [markdown]
# Độ tuổi tối đa của nam giới thuộc chủng tộc Amer-Indian-Eskimo là 82

# %% [markdown]
# ### 20. (6đ) Tỉ lệ người married hay single men (marital-status feature) chiếm nhiều hơn trong số những người kiếm được >50k? Những người có tình trạng hôn nhân (married) có marital-status feature bắt đầu với Married (Married-civ-spouse, Married-spouse-absent or Married-AF-spouse), còn lại được coi là single men.

# %%
more_than_50k = df[df['salary'] == ' >50K']
more_than_50k.shape[0]
# Out:
# 7841

# %%
married = more_than_50k[more_than_50k['marital_status'].str.contains('Married')].shape[0]
married
# Out:
# 6736

# %%
un_married = more_than_50k.shape[0] - married
un_married
# Out:
# 1105

# %% [markdown]
#  Tỉ lệ người married chiếm nhiều hơn trong số những người kiếm được >50k

# %% [markdown]
# ### 21. (6đ) Số giờ tối đa một người làm việc mỗi tuần (hours-per-week feature) là bao nhiêu? Có bao nhiêu người làm việc với số giờ như vậy và tỷ lệ những người kiếm được nhiều (>50K) trong số đó là bao nhiêu?

# %%
df['hours_per_week'].describe()
# Out:
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours_per_week, dtype: float64

# %%
work_99 = df[df['hours_per_week'] == 99].shape[0]

# %%
work_99_salary_50 = df[(df['hours_per_week'] == 99) & (df['salary'] == ' >50K')].shape[0]

# %%
# Ti le nguoi lam viec 99h va co muc luong >50k
work_99_salary_50/work_99*100
# Out:
# 29.411764705882355

# %% [markdown]
# ### 22. (10đ) Tính thời gian làm việc trung bình (số giờ mỗi tuần) của những người kiếm được ít và nhiều (salary feature) cho mỗi quốc gia (native-country feature). Với đất nước Nhật Bản thì kết quả như nào?

# %%
df.groupby(['native_country', 'salary'])['hours_per_week'].mean
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.generic.SeriesGroupBy object at 0x7c8d13a32e70>>

# %%
df[df['native_country']==' Japan'].groupby('salary')['hours_per_week'].mean()
# Out:
# salary
# <=50K    41.000000
# >50K     47.958333
# Name: hours_per_week, dtype: float64

# %% [markdown]
# ### 23. (10đ) Số người da trắng (white in race feature) kiếm được số tiền >50k ở nước Mỹ chiếm bao nhiêu phần trăm. Câu hỏi tương tự với người da đen (black in race feature).

# %%
all_white = df[(df['race'] == ' White')].shape[0]
all_black = df[(df['race'] == ' Black')].shape[0]

# %%
white = df[(df['race'] == ' White') & (df['salary'] == ' >50K') & (df['native_country'] == ' United-States')].shape[0]
print(white)
# Out:
# 6704

# %%
print(f'Proportion of white people with salary more than 50K in US: {white/all_white*100}%')
# Out:
# Proportion of white people with salary more than 50K in US: 24.101236698303136%

# %%
black = df[(df['race'] == ' Black') & (df['salary'] == ' >50K') & (df['native_country'] == ' United-States')].shape[0]

# %%
print(f'Proportion of black people with salary more than 50K in US: {black/all_black*100}%')
# Out:
# Proportion of black people with salary more than 50K in US: 11.235595390524967%
